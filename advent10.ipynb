# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('inputs/input10_test1.txt', delim_whitespace=True, header=None)
df.columns = ['val']
vals = df['val'].to_numpy()
vals
# Out:
# array([16, 10, 15,  5,  1, 11,  7, 19,  6, 12,  4])

# %%
builtin = max(vals) + 3
builtin
# Out:
# 22

# %%
v = np.sort(vals)
v
# Out:
# array([ 1,  4,  5,  6,  7, 10, 11, 12, 15, 16, 19])
