# %%
import pandas as pd

# %%
df = pd.read_csv('inputs/input08_test.txt', delim_whitespace=True, header=None)
df
# Out:
#      0   1
# 0  nop   0
# 1  acc   1
# 2  jmp   4
# 3  acc   3
# 4  jmp  -3
# 5  acc -99
# 6  acc   1
# 7  jmp  -4
# 8  acc   6
